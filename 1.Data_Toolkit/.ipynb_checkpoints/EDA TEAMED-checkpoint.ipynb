# %%
#import the warnings.
import warnings
warnings.filterwarnings('ignore')

# %%
#import the useful libraries.

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
inp = pd.read_csv('https://drive.google.com/file/d/1B8B6BK9T47e14BW8EWVXaRww1hdxoveZ/view?usp=sharing')

# %%
inp
# Out:
#     <!DOCTYPE html><html><head><meta name="google" content="notranslate"><meta http-equiv="X-UA-Compatible" content="IE=edge;"><style>@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:local('Roboto Italic')  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 175                  (function(){var a=_.qd();if(_.E(a
# 176                     }catch(e){_._DumpException(e)}
# 177                                    })(this.gbar_);
# 178                                     // Google Inc.
# 179  </script><script id="base-js" async type="text...
#
#         local('Roboto-Italic')  \
# 0                          NaN
# 1                          NaN
# 2                            6
# 3                          NaN
# 4                          NaN
# ..                         ...
# 175  18))Fj();else{var b=_.C(a
# 176                        NaN
# 177                        NaN
# 178                        NaN
# 179                        NaN
#
#     url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;src:local('Roboto Light')  \
# 0                                                    1
# 1                                                    5
# 2                                                    1
# 3                                                    1
# 4                                                  NaN
# ..                                                 ...
# 175              19)||0;window.addEventListener("load"
# 176                                                NaN
# 177                                                NaN
# 178                                                NaN
# 179                                                NaN
#
#                local('Roboto-Light')  \
# 0                                NaN
# 1                                  1
# 2                                  1
# 3                                NaN
# 4                                  1
# ..                               ...
# 175  function(){window.setTimeout(Fj
# 176                              NaN
# 177                              NaN
# 178                              NaN
# 179                              NaN
#
#     url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmSU5fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:local('Roboto Regular')  \
# 0                                                    0
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 175                                         b)})}})();
# 176                                                NaN
# 177                                                NaN
# 178                                                NaN
# 179                                                NaN
#
#     local('Roboto-Regular')  \
# 0                        1]
# 1                       NaN
# 2                       NaN
# 3                     [null
# 4                       NaN
# ..                      ...
# 175                     NaN
# 176                     NaN
# 177                     NaN
# 178                     NaN
# 179                     NaN
#
#     url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:700;src:local('Roboto Bold')  \
# 0                                                  NaN
# 1                                                    1
# 2                                                  NaN
# 3                                                  NaN
# 4                              https://docs.google.com
# ..                                                 ...
# 175                                                NaN
# 176                                                NaN
# 177                                                NaN
# 178                                                NaN
# 179                                                NaN
#
#          local('Roboto-Bold')  \
# 0                         NaN
# 1    https://drive.google.com
# 2                          3]
# 3                         NaN
# 4                         NaN
# ..                        ...
# 175                       NaN
# 176                       NaN
# 177                       NaN
# 178                       NaN
# 179                       NaN
#
#     url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfBBc9.ttf)format('truetype');}</style><meta name="referrer" content="origin"><title>application_data.csv - Google Drive</title><meta property="og:title" content="application_data.csv"><meta property="og:type" content="article"><meta property="og:site_name" content="Google Docs"><meta property="og:url" content="https://drive.google.com/file/d/1B8B6BK9T47e14BW8EWVXaRww1hdxoveZ/view?usp=sharing&amp;usp=embed_facebook"><link rel="shortcut icon" href="https://ssl.gstatic.com/docs/doclist/images/icon_14_text_favicon.ico"><link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Google+Sans:300  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                    1
# ..                                                 ...
# 175                                                NaN
# 176                                                NaN
# 177                                                NaN
# 178                                                NaN
# 179                                                NaN
#
#                                                    400  ... 1.4 null.13  \
# 0                                                  NaN  ... NaN     NaN
# 1                                                  NaN  ... NaN     NaN
# 2                                                  NaN  ... NaN     NaN
# 3    https://accounts.google.com/ServiceLogin?servi...  ... NaN     NaN
# 4                                                [null  ... NaN     NaN
# ..                                                 ...  ...  ..     ...
# 175                                                NaN  ... NaN     NaN
# 176                                                NaN  ... NaN     NaN
# 177                                                NaN  ... NaN     NaN
# 178                                                NaN  ... NaN     NaN
# 179                                                NaN  ... NaN     NaN
#
#     null.14 AIzaSyC1eQ1xj69IdTMeii5r7brs3R90eck-m7k null.15 /drive/v2beta 0.3  \
# 0       NaN                                     NaN     NaN           NaN NaN
# 1       NaN                                     NaN     NaN           NaN NaN
# 2       NaN                                     NaN     NaN           NaN NaN
# 3       NaN                                     NaN     NaN           NaN NaN
# 4       NaN                                     NaN     NaN           NaN NaN
# ..      ...                                     ...     ...           ...  ..
# 175     NaN                                     NaN     NaN           NaN NaN
# 176     NaN                                     NaN     NaN           NaN NaN
# 177     NaN                                     NaN     NaN           NaN NaN
# 178     NaN                                     NaN     NaN           NaN NaN
# 179     NaN                                     NaN     NaN           NaN NaN
#
#     0.4 1.5 [0]
# 0   NaN NaN NaN
# 1   NaN NaN NaN
# 2   NaN NaN NaN
# 3   NaN NaN NaN
# 4   NaN NaN NaN
# ..   ..  ..  ..
# 175 NaN NaN NaN
# 176 NaN NaN NaN
# 177 NaN NaN NaN
# 178 NaN NaN NaN
# 179 NaN NaN NaN
#
# [180 rows x 279 columns]
