# %%
import pandas as pd
data = pd.read_csv('https://drive.google.com/file/d/1bvmD0QRGsRqY5S4crefID1hZyx-k_JJP/view?usp=sharing')

# %%
data.describe()
# Out:
#        utm_content  docs-prn:""  docs-as:""  docs-mriim:1800000  \
# count          2.0     2.000000    2.000000                 1.0
# mean           0.0    32.000000   33.500000                64.0
# std            0.0    45.254834   47.376154                 NaN
# min            0.0     0.000000    0.000000                64.0
# 25%            0.0    16.000000   16.750000                64.0
# 50%            0.0    32.000000   33.500000                64.0
# 75%            0.0    48.000000   50.250000                64.0
# max            0.0    64.000000   67.000000                64.0
#
#        docs-eccbs:false  docs-erd:false  docs-erfar:false  docs-uootuns:false  \
# count               1.0        2.000000          2.000000                 1.0
# mean               67.0       32.000000         33.500000                99.0
# std                 NaN       45.254834         47.376154                 NaN
# ...
