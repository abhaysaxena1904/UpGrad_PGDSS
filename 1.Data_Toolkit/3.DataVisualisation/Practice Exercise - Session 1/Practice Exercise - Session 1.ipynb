# %%
#Import all the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### I - Virat Kohli Dataset

# %%
df = pd.read_csv("virat.csv")

# %%
df
# Out:
#     Runs Mins   BF  4s  6s      SR  Pos Dismissal  Inns     Opposition  \
# 0     12   33   22   1   0   54.54    2       lbw     1    v Sri Lanka
# 1     37   82   67   6   0   55.22    2    caught     2    v Sri Lanka
# 2     25   40   38   4   0   65.78    1   run out     1    v Sri Lanka
# 3     54   87   66   7   0   81.81    1    bowled     1    v Sri Lanka
# 4     31   45   46   3   1   67.39    1       lbw     2    v Sri Lanka
# ..   ...  ...  ...  ..  ..     ...  ...       ...   ...            ...
# 127   45   64   51   2   1   88.23    3    caught     2  v New Zealand
# 128   65  152   76   2   1   85.52    3    caught     1  v New Zealand
# 129  122  147  105   8   5  116.19    3    caught     2      v England
# 130    8    6    5   2   0     160    3    caught     1      v England
# 131   55   81   63   8   0    87.3    3    caught     2      v England
#
#             Ground Start Date
# 0         Dambulla  18-Aug-08
# 1         Dambulla  20-Aug-08
# ...

# %%
df.dtypes
# Out:
# Runs          object
# Mins          object
# BF             int64
# 4s             int64
# 6s             int64
# SR            object
# Pos            int64
# Dismissal     object
# Inns           int64
# Opposition    object
# Ground        object
# Start Date    object
# dtype: object

# %%
df['Runs'] = df['Runs'].str.replace('*', '')
#df['Runs']= df['Runs'].apply(lambda x: int(x[:-1]) if x[-1]=="*" else int(x))

# %%
df.Runs.value_counts()
# Out:
# 0      10
# 2       6
# 1       5
# 9       4
# 31      4
#        ..
# 139     1
# 53      1
# 49      1
# 45      1
# 55      1
# Name: Runs, Length: 75, dtype: int64

# %%
df.Runs=df.Runs.astype('int')

# %% [markdown]
# #### Spread in Runs
# Question 1: Analyse the spread of Runs scored by Virat in all his matches and report the difference between the scores at the 50th percentile and the 25th percentile respectively.
#
#     a)16.5
#     b)22.5
#     c)26.5
#     d)32.5

# %%
## Your code here
#df['Runs'].describe(percentiles = [0.25,0.5,1]) 

df.Runs.describe()
# Out:
# count    132.000000
# mean      46.848485
# std       41.994635
# min        0.000000
# 25%       10.000000
# 50%       32.500000
# 75%       80.250000
# max      154.000000
# Name: Runs, dtype: float64

# %% [markdown]
# #### Box Plots
#
# Question 2: Plot a Box Plot to analyse the spread of Runs that Virat has scored. The upper fence in the box plot lies in which interval?
#
#     a)100-120
#     b)120-140
#     c)140-160
#     d)160-180

# %%
#Your code here
df.Runs.plot.box()
plt.show()

# %% [markdown]
# #### False Statement
#
# Q3:Consider the following statements and choose the correct option
#
#      I - Virat has played the maximum number of matches in 2011
#      II - Virat has the highest run average in the year 2017
#      III - Virat has the maximum score in a single match and the highest run average in the year 2016.
#
# Which of the above statements is/are false?
#
#     a)I and II
#     b)I and III
#     c)II
#     d)III

# %%
## Your code here
plt.hist(df['Start Date'],)
plt.show()

# %%
df['Start Date'].value_counts()
# Out:
# 20-Oct-16    1
# 31-Jan-14    1
# 18-Jan-11    1
# 24-Jun-10    1
# 5-Sep-14     1
#             ..
# 24-Dec-09    1
# 20-Aug-08    1
# 12-Jan-11    1
# 4-Dec-10     1
# 20-Jan-16    1
# Name: Start Date, Length: 132, dtype: int64

# %%
#df['month'] = pd.DatetimeIndex(df['Start Date']).month
df['year'] = pd.DatetimeIndex(df['Start Date']).year
df
# Out:
#      Runs Mins   BF  4s  6s      SR  Pos Dismissal  Inns     Opposition  \
# 0      12   33   22   1   0   54.54    2       lbw     1    v Sri Lanka
# 1      37   82   67   6   0   55.22    2    caught     2    v Sri Lanka
# 2      25   40   38   4   0   65.78    1   run out     1    v Sri Lanka
# 3      54   87   66   7   0   81.81    1    bowled     1    v Sri Lanka
# 4      31   45   46   3   1   67.39    1       lbw     2    v Sri Lanka
# ..    ...  ...  ...  ..  ..     ...  ...       ...   ...            ...
# 127    45   64   51   2   1   88.23    3    caught     2  v New Zealand
# 128    65  152   76   2   1   85.52    3    caught     1  v New Zealand
# 129   122  147  105   8   5  116.19    3    caught     2      v England
# 130     8    6    5   2   0     160    3    caught     1      v England
# 131    55   81   63   8   0    87.3    3    caught     2      v England
#
#             Ground Start Date  year
# 0         Dambulla  18-Aug-08  2008
# ...

# %%
plt.hist(df['year'])
plt.show()

# %%
# to answer these questions main requirement


df.groupby(['year']).Runs.describe()
# Out:
#       count       mean        std   min    25%   50%     75%    max
# year
# 2008    5.0  31.800000  15.482248  12.0  25.00  31.0   37.00   54.0
# 2009    6.0  38.333333  38.161062   2.0  14.25  28.5   48.00  107.0
# 2010   16.0  45.375000  41.269642   0.0   8.00  34.0   70.75  118.0
# 2011   31.0  42.000000  38.627279   0.0   9.00  28.0   80.50  117.0
# 2012   11.0  40.363636  42.306673   0.0  15.00  23.0   52.00  128.0
# 2013   23.0  47.826087  40.554847   0.0  12.50  37.0   81.50  115.0
# 2014   17.0  58.529412  49.572066   0.0  13.00  53.0   82.00  139.0
# 2015   10.0  30.400000  43.820847   1.0   7.50  11.5   24.50  138.0
# 2016   10.0  73.900000  46.441002   8.0  48.50  75.0  102.25  154.0
# 2017    3.0  61.666667  57.291652   8.0  31.50  55.0   88.50  122.0

# %%
df.Runs.describe()
# Out:
# count    132.000000
# mean      46.848485
# std       41.994635
# min        0.000000
# 25%       10.000000
# 50%       32.500000
# 75%       80.250000
# max      154.000000
# Name: Runs, dtype: float64

# %%
df[(df.Runs == 154)]
# Out:
#      Runs Mins   BF  4s  6s      SR  Pos Dismissal  Inns     Opposition  \
# 126   154  202  134  16   1  114.92    3   not out     2  v New Zealand
#
#      Ground Start Date  year
# 126  Mohali  23-Oct-16  2016

# %% [markdown]
# #### Maximum Frequency
#
# Q4:Plot a histogram for the Mins column with 15 bins. Among the three ranges mentioned below, which one has the highest frequency?
#
# A - [54.6,68)
#
# B - [68,81.4)
#
# C - [121.6,135)
#
#     a)A - [54.6,68)
#     b)B - [68,81.4)
#     c)C - [121.6,135)
#     d)All the bin ranges have the same frequency

# %%
df.Mins.value_counts()
# Out:
# -      6
# 11     4
# 9      4
# 82     3
# 1      3
#       ..
# 134    1
# 78     1
# 2      1
# 12     1
# 154    1
# Name: Mins, Length: 93, dtype: int64

# %%
#Your code here
df.Mins=df.Mins.apply(lambda x: int(0) if x=='-' else int(x))
df.Mins=df.Mins.astype('int32')
plt.hist(df['Mins'],bins=15)
plt.show()
df.Mins.describe()
# Out:
# count    132.000000
# mean      67.287879
# std       57.852343
# min        0.000000
# 25%       13.750000
# 50%       48.000000
# 75%      120.000000
# max      202.000000
# Name: Mins, dtype: float64
